# %% [markdown]
# ## Código para passar as imagens para Preto & Branco

# %% [markdown]
# #### Pacotes necessários

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
#from PIL import Image as Img
from skimage import io, color

#lina_color = io.imread(path+img)
#lina_gray = color.rgb2gray(lina_color)

# %% [markdown]
# ##### Diretório de trabalho

# %%
os.getcwd()
# Out:
# '/home/jovyan/work'

# %% [markdown]
# ##### Imagens a serem convertidas

# %%
os.listdir("valendo")
# Out:
# ['Yuri2.jpg',
#  'Renato1.jpg',
#  'Wagner1.jpg',
#  'Renato.jpg',
#  'Soledad1.jpg',
#  'Yuri3.jpg',
#  'Soledad.jpg',
#  'Camacho1.jpg',
#  'Camacho2.jpg',
#  'Camacho.jpg',
#  'Wagner4.jpg',
#  'Wagner3.jpg',
#  'Renato4.jpg',
#  'Renato3.jpg',
#  'Yuri.jpg',
#  'Soledad2.jpg',
#  'Camacho4.jpg',
#  'Camacho3.jpg',
#  'Yuri1.jpg',
#  'Wagner.jpg',
#  'Renato2.jpg',
#  'Wagner2.jpg']

# %% [markdown]
# ### Função de conversão (OLD)

# %%
#def rgb2gray(rgb):
#    return np.dot(rgb[...,:3], [0.299, 0.587, 0.144])

# %% [markdown]
# ### Estrutura de repetição para conversão de todas as imagens. Skimage foi usado pois é o único que salva Grayscale em arrays de 2 dimensões.

# %%
#imgs = os.listdir("valendo")
#for i in imgs:
#    img = mpimg.imread("valendo/" + i)
#    plt.imshow(image, cmap = plt.get_cmap('gray'))
#    plt.axis("off")
#    plt.savefig("/home/jovyan/work/imgs/" + i) #salva via pyplot pois o mesmo diminui a resolução consideravelmente, de acordo com a DPI, poupando trabalho.
#    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e180aa1081b9> in <module>
#       2 for i in imgs:
#       3     img = mpimg.imread("valendo/" + i)
# ----> 4     plt.imshow(image, cmap = plt.get_cmap('gray'))
#       5     plt.axis("off")
#       6     plt.savefig("/home/jovyan/work/imgs/" + i) #salva via pyplot pois o mesmo diminui a resolução consideravelmente, de acordo com a DPI, poupando trabalho.
#
# NameError: name 'image' is not defined

# %% [markdown]
# ### pyplot salva as imagens de acordo com DPI, logo foi preciso fazer recortes. A biblioteca mais eficiente e simples nesse sentido foi cv2(compatível com NumPy)

# %%
#imgs = os.listdir("imgs")
#y = 29 #onde começa o corte verticalmente.
#x = 120 #onde começa o corte horizontalmente.
#w = 195 #largura que eu quero, compatível com o dataset de exemplo.
#h = 231 #altura que eu quero, compatível com o dataset de exemplo.
#for i in imgs:
#    image = cv2.imread("imgs/" + i)
#    crop = image[y:y+h, x:x+w] #notação de NumPy
#    #cv2.imshow('Image', crop)
#    cv2.imwrite(f"imgs/{i}", crop)

# %%
imgs = os.listdir("a")
for i in imgs:
    img = io.imread("a/" + i)
    img = color.rgb2gray(img)
    io.imsave("a/" + i, img)
# Out:
# /opt/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   after removing the cwd from sys.path.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
